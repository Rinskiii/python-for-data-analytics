# %%
import ast
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/home/renat/Desktop/programming/data_science/youtube/luke_barousse/python-for-data-analytics/data/data_jobs.csv')

# %%
df.head(3)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
#
#                    job_location           job_via job_schedule_type  \
# 0                 Watertown, CT   via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico  via BeBee México         Full-time
# 2               Berlin, Germany      via LinkedIn         Full-time
#
#    job_work_from_home       search_location      job_posted_date  \
# 0               False  Texas, United States  2023-06-16 13:44:15
# 1               False                Mexico  2023-01-14 13:18:07
# 2               False               Germany  2023-10-10 13:14:55
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# 0                  False                 False  United States         NaN
# 1                  False                 False         Mexico         NaN
# 2                  False                 False        Germany         NaN
#
#    salary_year_avg  salary_hour_avg                company_name  \
# 0              NaN              NaN        Boehringer Ingelheim
# 1              NaN              NaN  Hewlett Packard Enterprise
# 2              NaN              NaN    ALPHA Augmented Services
#
#                                           job_skills  \
# 0                                                NaN
# 1  ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2  ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
#
#                                      job_type_skills
# 0                                                NaN
# 1  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2  {'analyst_tools': ['dax'], 'cloud': ['azure'],...

# %%
df_zoom = df[df['company_name'] == 'Zoom']
df_zoom
# Out:
#                   job_title_short                          job_title  \
# 32530         Senior Data Analyst           Senior Data Analyst, GTM
# 33661        Senior Data Engineer      Senior Data Engineer - Remote
# 101931        Senior Data Analyst           Senior Data Analyst, GTM
# 112400          Software Engineer  Data Engineer / Software Engineer
# 117162             Data Scientist                     Data Scientist
# ...                           ...                                ...
# 715562              Data Engineer      Data Loss Prevention Engineer
# 737735             Data Scientist                     Data Scientist
# 739265       Senior Data Engineer               Senior Data Engineer
# 750871  Machine Learning Engineer          Machine Learning Engineer
# 768699              Data Engineer      Data Loss Prevention Engineer
#
#                        job_location               job_via job_schedule_type  \
# 32530             San Francisco, CA           via Ladders         Full-time
# 33661                      Anywhere         via Jobgether         Full-time
# 101931                 San Jose, CA       via Recruit.net         Full-time
# 112400                        India          via MNC Jobs         Full-time
# 117162  Bengaluru, Karnataka, India          via LinkedIn         Full-time
# ...                             ...                   ...               ...
# 715562                    Singapore          via LinkedIn         Full-time
# 737735  Bengaluru, Karnataka, India       via BeBee India         Full-time
# 739265  Bengaluru, Karnataka, India          via LinkedIn         Full-time
# 750871                    Singapore  via Jobs Trabajo.org         Full-time
# 768699                    Singapore      via Zoom Careers         Full-time
#
#         job_work_from_home            search_location      job_posted_date  \
# 32530                False  California, United States  2023-06-16 13:00:44
# 33661                 True                      India  2023-10-11 13:10:56
# 101931               False  California, United States  2023-05-28 00:00:36
# 112400               False                      India  2023-01-25 00:14:45
# 117162               False                      India  2023-02-28 08:17:34
# ...                    ...                        ...                  ...
# 715562               False                  Singapore  2023-09-29 02:57:03
# 737735               False                      India  2023-03-08 21:13:14
# 739265               False                      India  2023-12-05 21:11:36
# 750871               False                  Singapore  2023-11-24 20:27:26
# 768699               False                  Singapore  2023-09-29 01:56:59
#
#         job_no_degree_mention  job_health_insurance    job_country  \
# 32530                   False                 False  United States
# 33661                   False                 False          India
# 101931                  False                  True  United States
# 112400                  False                 False          India
# 117162                  False                 False          India
# ...                       ...                   ...            ...
# 715562                   True                 False      Singapore
# 737735                  False                 False          India
# 739265                  False                 False          India
# 750871                  False                 False      Singapore
# 768699                  False                 False      Singapore
#
#        salary_rate  salary_year_avg  salary_hour_avg company_name  \
# 32530         year         150000.0              NaN         Zoom
# 33661          NaN              NaN              NaN         Zoom
# 101931         NaN              NaN              NaN         Zoom
# 112400         NaN              NaN              NaN         Zoom
# 117162         NaN              NaN              NaN         Zoom
# ...            ...              ...              ...          ...
# 715562         NaN              NaN              NaN         Zoom
# 737735         NaN              NaN              NaN         Zoom
# 739265         NaN              NaN              NaN         Zoom
# 750871         NaN              NaN              NaN         Zoom
# 768699         NaN              NaN              NaN         Zoom
#
#                                                job_skills  \
# 32530   ['sql', 'python', 'r', 'tableau', 'jira', 'zoom']
# 33661   ['python', 'java', 'scala', 'sql', 'r', 'snowf...
# 101931  ['sql', 'python', 'r', 'tableau', 'jira', 'zoom']
# 112400  ['python', 'sql', 'javascript', 'c++', 'aws', ...
# 117162                          ['sql', 'python', 'zoom']
# ...                                                   ...
# 715562                        ['windows', 'unix', 'zoom']
# 737735                                  ['sql', 'python']
# 739265  ['python', 'java', 'scala', 'sql', 'r', 'snowf...
# 750871  ['python', 'java', 'tensorflow', 'pytorch', 'a...
# 768699                        ['windows', 'unix', 'zoom']
#
#                                           job_type_skills
# 32530   {'analyst_tools': ['tableau'], 'async': ['jira...
# 33661   {'async': ['jira'], 'cloud': ['snowflake', 'aw...
# 101931  {'analyst_tools': ['tableau'], 'async': ['jira...
# 112400  {'cloud': ['aws'], 'libraries': ['hadoop'], 'o...
# 117162  {'programming': ['sql', 'python'], 'sync': ['z...
# ...                                                   ...
# 715562      {'os': ['windows', 'unix'], 'sync': ['zoom']}
# 737735                 {'programming': ['sql', 'python']}
# 739265  {'async': ['jira'], 'cloud': ['snowflake', 'aw...
# 750871  {'libraries': ['tensorflow', 'pytorch', 'airfl...
# 768699      {'os': ['windows', 'unix'], 'sync': ['zoom']}
#
# [70 rows x 17 columns]

# %%
df_zoom.shape
# Out:
# (70, 17)
